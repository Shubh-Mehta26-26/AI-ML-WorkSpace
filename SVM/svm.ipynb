# %%
import pandas as pd

# %%
data=pd.read_csv("fruitdataset.csv")
data.head()
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %%
data.isnull().sum()
# Out:
# Weight    0
# Size      0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.Class=le.fit_transform(data.Class)
data.head()
# Out:
#    Weight  Size  Class
# 0      69  4.39      1
# 1      69  4.21      1
# 2      65  4.09      1
# 3      72  5.85      0
# 4      67  4.70      1

# %%
from sklearn.model_selection import train_test_split
x=data[['Weight','Size']]
y=data.Class
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import LinearSVC
import warnings
warnings.simplefilter("ignore")
classifier=LinearSVC()
classifier.fit(xtrain,ytrain)

LinearSVC()
# Out:
# LinearSVC()

# %%
print("Trainig Accuracy= ",classifier.score(xtrain,ytrain))
print("Testing Accuracy=",classifier.score(xtest,ytest))
# Out:
# Trainig Accuracy=  0.875
# Testing Accuracy= 1.0

# %%
ypred=classifier.predict(xtest)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(ytest,ypred))
# Out:
# [[4 0]
#  [0 4]]

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8

# %%
from mlxtend.plotting import plot_decision_regions
import numpy as np
import matplotlib.pyplot as plt

plot_decision_regions(
    x.values,
    np.array(y),
    clf=classifier,
    legend=2
)

plt.title('SVM Decision Region Boundary', size=16)
plt.show()

# %%
pip install mlxtend
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 2.5 MB/s eta 0:00:00
# Collecting pandas>=2.3.3
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#      ---------------------------------------- 11.3/11.3 MB 3.4 MB/s eta 0:00:00
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.15.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shubh\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubh\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip available: 22.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
